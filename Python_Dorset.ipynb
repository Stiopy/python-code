# %%
import math
import numpy as np

# %%
cities = ['Moscow', 'Paris', 'Dublin', 'London', 'New York', 'Singapore']

# %%
cities.append('Roma')
for city in cities:
    print(city)
# Out:
# Moscow
# Paris
# Dublin
# London
# New York
# Singapore
# Roma

# %%
print(cities[0])
# Out:
# Moscow

# %%
cities.remove('Roma')

# %%
for city in cities:
    print(city)
# Out:
# Moscow
# Paris
# Dublin
# London
# New York
# Singapore

# %%
print(cities [5] [1])
# Out:
# i

# %%
n = int(input("Entrez un nombre : "))
my_list = []
for i in range(1, n + 1):
    my_list.append(1 / i)
print("La somme est {}".format(sum(my_list)))
# Out:
# Entrez un nombre :  2
# La somme est 1.5

# %%
n = int(input("Entrez un nombre : "))
my_list = []
for i in range(0, n + 1):
    my_list.append(i**2)
print(f"Liste : {my_list}")

# %%
names = []
grades = []
while True:
    name = input("Enter the student's name (or press Enter to finish): ")
    if name == "":
        break
    try:
        grade = float(input("Enter the student's grade out of 10: "))
        if 0 <= grade <= 10:
            names.append(name)
            grades.append(grade)
        else:
            print("Grade should be between 0 and 10. Please try again.")
    except ValueError:
        print("Invalid grade. Please enter a numeric value.")
if len(grades) > 0:
    mean_grade = sum(grades) / len(grades)
else:
    mean_grade = 0
print("\n{:<14} {:<5}".format("Name", "Grade"))
print("-" * 20)
for name, grade in zip(names, grades):
    print("{:<14} {:5.1f}".format(name, grade))
print("\nArithmetic Mean: {:5.1f}".format(mean_grade))
# Out:
# Enter the student's name (or press Enter to finish):  Stepane
# Enter the student's grade out of 10:  g
# Invalid grade. Please enter a numeric value.
# Enter the student's name (or press Enter to finish):  Stepane
# Enter the student's grade out of 10:  11
# Grade should be between 0 and 10. Please try again.
# Enter the student's name (or press Enter to finish):
# Name           Grade
# --------------------
#
# Arithmetic Mean:   0.0

# %%
nums = []
while True:
    try:
        num_input = input("Enter your value (or press Enter to finish): ")       
        if num_input == "":
            break    
        num = float(num_input)
        nums.append(num)
    except ValueError:
        print("Please enter a numeric value.")
if len(nums) > 0:
    mean = sum(nums) / len(nums)
else:
    mean = 0
print("-" * 20)
print("\nArithmetic Mean: {:5.1f}".format(mean))

# %%
name = str(input("Enter names separated by blanks"))
list_name = name.split(" ")
for i in range (len(list_name)):
    print(f"Hi {list_name[i]}")
print (len(list_name))

# %%
elements = ['H', 'C', 'N', 'O', 'S', 'Cl']
poids_atomiques = [1.00784, 12.011, 14.00674, 15.999, 32.06, 35.453]

nombre_atomes = [int(input(f"Nombre d'atomes de {element} : ")) for element in elements]

masse_totale = sum(nombre * poids for nombre, poids in zip(nombre_atomes, poids_atomiques))

print(f"La masse totale de la molécule est : {masse_totale} g/mol")

# %%
while True:
    try:
        degree = int(input("Entrez le degré maximal n du polynôme : "))
        coef = []
        for i in range(degree + 1):
            value = float(input(f"Entrez la valeur du coefficient {i} : "))
            coef.append(value)
        x = float(input("Entrez la valeur de x : "))
        break
    except ValueError:
        print("Veuillez entrer une valeur numérique valide.")

result = 0
for i in range(len(coef)):
    result += coef[i] * x**i

print(f"Pour x = {x}, la valeur est : {result}.")

# %%
country_capitals = {"United States": "Washington D.C.",
                    "Italy": "Rome",
                    "England": "London"}
print(country_capitals)
# Out:
# {'United States': 'Washington D.C.', 'Italy': 'Rome', 'England': 'London'}

# %%
Dict = dict({1: 'Geeks', 2: 'For', 3: 'Geeks'})
print(Dict)
# Out:
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}

# %%
Dict = dict({(1,'Geeks'), (2,'For'), (3,'Geeks')})
print(Dict)
# Out:
# {3: 'Geeks', 1: 'Geeks', 2: 'For'}

# %%
print(Dict[1])
# Out:
# Geeks

# %%
country_capitals ["Russia"]="Moscow"

# %%
for i in country_capitals:
    print(i)
    print(country_capitals[i])
# Out:
# United States
# Washington D.C.
# Italy
# Rome
# England
# London
# Russia
# Moscow

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
dic={}
for i, j in zip (keys, values):
    dic[i]=j
print (dic)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
dic=dict(zip(keys,values))
print(dic)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %%
sample_dict = {
    'emp1':{'name': 'Jhon', 'salary': 7500},
    'emp2':{'name': 'Emma', 'salary': 8000},
    'emp3':{'name': 'Brad', 'salary': 500}}
sample_dict ['emp3']['salary']=8500
print(sample_dict)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %%
#Problem1
periodictable = {"H": {"atomicnumber":1,"meltingPoint":14,"boilingPoint":20},
                  "He": {"atomicnumber":2,"meltingPoint":1,"boilingPoint":4},
                  "Li": {"atomicnumber":3,"meltingPoint":453,"boilingPoint":1603},
                  "Be": {"atomicnumber":4,"meltingPoint":1560,"boilingPoint":2742},
                  "B": {"atomicnumber":5,"meltingPoint":2349,"boilingPoint":4200},
                  "C": {"atomicnumber":6,"meltingPoint":3915,"boilingPoint":3915},
                  "N": {"atomicnumber":7,"meltingPoint":63,"boilingPoint":77},
                  "O": {"atomicnumber":8,"meltingPoint":54,"boilingPoint":90},
                  "F": {"atomicnumber":9,"meltingPoint":53,"boilingPoint":85},
                  "Ne": {"atomicnumber":10,"meltingPoint":25,"boilingPoint":27}}
value = str(input("What is the element ? "))
temp = int(input("What's the temperature ? "))
if temp < periodictable[value]["meltingPoint"]:
    print("{} is solid".format(value))
elif (temp < periodictable[value]["boilingPoint"]) and (temp > periodictable[value]["meltingPoint"]):
    print("{} is liquid".format(value))
else:
    print("{} is gas".format(value))

# %%
#Problem2
interestrates = {
    "ANZ": {"year1and2": 2.3, "year3": 4.1},
    "Bank of Australia": {"year1and2": 0.1, "year3": 5.0},
    "Commonwealth Bank": {"year1and2": 3.5, "year3": 3.8},
    "Westpac": {"year1and2": 3.7, "year3": 3.7}}


names = str(input("What's the name of the bank ? "))
years = int(input("How many years do they stay ? "))
principal = int(input("What's the value of the payment ? "))
if names:
        if years <= 2:
            interest_rate = interestrates[names]["year1and2"]/100
        else:
            interest_rate = interestrates[names]["year3"]/100
            
#        monthly_payment = principal * (monthly_interest_rate * (1 + monthly_interest_rate) * num_payments) / ((1 + monthly_interest_rate) * num_payments - 1)
        monthly_payment = (principal + principal*interest_rate)/(years*12)

        print(f"For {principal} $ at the bank {names} in {years} years :")
        print(f"The mortgage repayments {monthly_payment:.2f} $")

else:
        print("The bank doesn't exist.")

# %%
def f(a,b):
    print(a+" "+b)
f("salut","salut")
# Out:
# salut salut

# %%
def f(a):
    return 3*a

# %%
def f(a, b):
    return max(a, b)
print (f(2, 5))
# Out:
# 5

# %%
while True:
    try:
        num = int(input("Enter  a number : "))
        if (num%2)==0:
            print(f"{num} is Even")
        else:
            print(f"{num} is Odd")
    except:
        print("Please enter an int.")
# Out:
# Enter  a number :  5
# 5 is Odd
# Enter  a number :
# Please enter an int.
# Enter  a number :
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.
# Please enter an int.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(-2,2,101)

# %%
x = np.linspace(-2,2,101)
y = x**2
print(x)
plt.plot(x,y)
plt.show()
# Out:
# [-2.   -1.96 -1.92 -1.88 -1.84 -1.8  -1.76 -1.72 -1.68 -1.64 -1.6  -1.56
#  -1.52 -1.48 -1.44 -1.4  -1.36 -1.32 -1.28 -1.24 -1.2  -1.16 -1.12 -1.08
#  -1.04 -1.   -0.96 -0.92 -0.88 -0.84 -0.8  -0.76 -0.72 -0.68 -0.64 -0.6
#  -0.56 -0.52 -0.48 -0.44 -0.4  -0.36 -0.32 -0.28 -0.24 -0.2  -0.16 -0.12
#  -0.08 -0.04  0.    0.04  0.08  0.12  0.16  0.2   0.24  0.28  0.32  0.36
#   0.4   0.44  0.48  0.52  0.56  0.6   0.64  0.68  0.72  0.76  0.8   0.84
#   0.88  0.92  0.96  1.    1.04  1.08  1.12  1.16  1.2   1.24  1.28  1.32
#   1.36  1.4   1.44  1.48  1.52  1.56  1.6   1.64  1.68  1.72  1.76  1.8
#   1.84  1.88  1.92  1.96  2.  ]

# %%
x = np.linspace(0, 3*np.pi, 500)
plt.plot(x,np.sin(x**2))
plt.title("A simple chirp")

# %%
x = np.linspace(-2,2,101)
y = x**2
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(-2,2,101)
y = x**2
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(-2,2,101)
y = x**2
plt.xlabel("x")
plt.ylabel("f(x)")
plt.xlim(-1.5,1.5)
plt.ylim(-0.5,2.5)
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(-2,2,101)
plt.xlabel("x")
plt.ylabel("f(x)")
y = x**2
plt.plot(x,y)
y2 = x**4
plt.plot(x,y2)
plt.show()

# %%
x = np.linspace(-2,2,101)
plt.xlabel("x")
plt.ylabel("f(x)")
y = x**2
plt.plot(x,y,label = "x ^ 2")
y2 = x**4
plt.plot(x,y2,label = "x ^ 4")
plt.legend()
plt.show()

# %%
x = np.linspace(-2,2,101)
plt.xlabel("x")
plt.ylabel("f(x)")
y = x**2
plt.plot(x,y,'g',label = "x ^ 2")
y2 = x**3
plt.plot(x,y2,'ro',label = "x ^ 3")
y3 = x**4
plt.plot(x,y3,'b.',label = "x ^ 4")
plt.legend()
plt.show()

# %%
x = np.linspace(-2,2,101)
plt.xlabel("x")
plt.ylabel("f(x)")
y = x**2
plt.plot(x,y,label = "x ^ 2")
y2 = x**4
plt.plot(x,y2,label = "x ^ 4")
plt.legend()
plt.show()

# %%
n = int(input("Enter number of points :"))
x = np.linspace(-1,1,n)
plt.xlabel("x")
plt.ylabel("f(x)")
y = np.cos(2*x*np.pi)
plt.plot(x,y,label = "2pix")
plt.legend()
plt.show()
# Out:
# Enter number of points : 101

# %%
n = int(input("Enter number of points :"))
x = np.linspace(-1,1,n)
plt.xlabel("x")
plt.ylabel("f(x)")
y1 = np.cos(2*x*np.pi)
plt.plot(x,y1,'r',label = "cos(2pix)")
y2 = np.sin(2*x*np.pi)
plt.plot(x,y2,'b',label = "sin(2pix)")
plt.legend()
plt.show()
# Out:
# Enter number of points : 101

# %%
while True:
    try:
        n = input("Enter number of points (press Enter to exit): ")
        if n == "":
            break
        n = int(n)
        if n > 0:
            x = np.linspace(0, 4, n)
            plt.xlabel("x")
            plt.ylabel("f(x)")
            y = np.sin(x * np.pi) * np.sin(20 * np.pi * x) * np.exp(-x)
            plt.plot(x, y, 'r', label="sin(pix)*sin(20pix)*e^(-x)")
            plt.legend()
            plt.show()
    except ValueError:
        print("Please enter a valid number or press Enter to exit.")
# Out:
# Enter number of points (press Enter to exit):

# %%
while True:
  try:
    n = int(input("What is the number of points : "))
    T = int(input("What is the temperature : "))
    if n>=1 and T>=1:
      break
  except:
    print("Error.Please enter a valide number :")
x = np.linspace(2,10,n)
y = (0.08206*T)/x
plt.xlabel("Vm")
plt.ylabel("p")
plt.plot(x,y,'b',label="p = RT/Vm")
plt.title("Isotherm (ideal gas)")
plt.legend()
plt.show()
# Out:
# What is the number of points :  100
# What is the temperature :  20

# %%
try:
    num_temperatures = int(input("Enter the number of temperatures: "))
    if num_temperatures >= 1:
        temperatures = []

        for _ in range(num_temperatures):
            while True:
                try:
                    T = int(input("Enter a temperature (T): "))
                    if T >= 1:
                        temperatures.append(T)
                        break
                except:
                    print("Error. Please enter a valid number.")

        n = int(input("What is the number of points: "))
        if n >= 1:
            x = np.linspace(2, 10, n)

            plt.xlabel("Vm")
            plt.ylabel("p")
            plt.title("Isotherm (ideal gas)")

            for T in temperatures:
                y = (0.08206 * T) / x
                plt.plot(x, y, label=f"p = RT/Vm, T={T} K")

            plt.legend()
            plt.show()
        else:
            print("Error: Number of points should be greater than or equal to 1.")
except ValueError:
    print("Error: Please enter a valid number for the number of temperatures.")
# Out:
# Enter the number of temperatures:  3
# Enter a temperature (T):  12
# Enter a temperature (T):  16
# Enter a temperature (T):  22
# What is the number of points:  100

# %%
xo = float(input("Enter the value of xo : "))
s = float(input("Enter the value of s : "))
x0 = float(input("Enter the value of x0 : "))
xn = float(input("Enter the value of xn : "))
n = int(input("Enter the number of points : "))

x = np.linspace(x0, xn, n)
y = (1 / (np.sqrt(2 * np.pi) * s)) * np.exp(-(x - xo)**2 / (2 * s**2))

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Fonction gaussienne")
plt.show()
# Out:
# Enter the value of xo :  0
# Enter the value of s :  0.3
# Enter the value of x0 :  -1
# Enter the value of xn :  1
# Enter the number of points :  500

# %%
x=np.linspace(-1,1,101)
y=x**2
plt.xlabel('x')
plt.ylabel('f(x)')
plt.plot(x, y, 'r', label='x^2')
plt.legend()
plt.show()

# %%
list_test=[1,2,3,4,5]
tuplet=('Stepane','Isaline')
set_test={'Bangkok','Singapore'}
dict_test={'France':'Paris','Russie':'Moscou'}
print(list_test)
print(tuplet)
print(set_test)
print(dict_test)
# Out:
# [1, 2, 3, 4, 5]
# ('Stepane', 'Isaline')
# {'Bangkok', 'Singapore'}
# {'France': 'Paris', 'Russie': 'Moscou'}

# %%
dict_test['Royaume-Uni']='Londres'
list_test.append('Liocha')
list_test.remove(5)
print(dict_test)
print(list_test)
# Out:
# {'France': 'Paris', 'Russie': 'Moscou', 'Royaume-Uni': 'Londres'}
# [1, 2, 3, 4, 'Liocha']

# %%
x=int(input('Entrez une valeur : '))
y=x**2
print(f'Le carré de votre nombre est : {y}')
# Out:
# Entrez une valeur :  2
# Le carré de votre nombre est : 4
